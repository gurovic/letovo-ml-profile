# %% [markdown]
# # Доверительные интервалы и ограничения корреляции

# %% [markdown]
# ## Маршрут работы
#
# **Фокус:** Неопределённость эффекта и границы корреляции.
#
# Bootstrap показывает диапазон правдоподобных uplift, а корреляции помогают искать связи. Ни один из этих инструментов сам по себе не доказывает причинность.
#
# **Правило работы:** выполняйте ячейки сверху вниз, заменяйте `None` и пустые строки, а после каждого шага добивайтесь зелёных `assert`. Не удаляйте проверки: они задают контракт результата.
#
# **Что сдаём:** выполненный ноутбук, численный результат и короткую интерпретацию без причинных обещаний.

# %%
from pathlib import Path
import numpy as np
import pandas as pd


def _find(name):
    for path in (
        Path(name),
        Path("../") / name,
        Path("../../data") / name,
        Path("../data") / name,
        Path("../../../data") / name,
    ):
        if path.exists():
            return path.resolve()
    return "https://raw.githubusercontent.com/gurovic/letovo-ml-profile/main/modules/08_06_ab_startup/data/" + name


CSV_PATH = _find('startup_ab.csv')
df = pd.read_csv(CSV_PATH)
df['variant_b'] = (df['variant'] == 'B').astype(int)

# %% [markdown]
# ## 0.1. Точечная оценка uplift
#
# Перед bootstrap посчитайте estimand B−A. Интервал далее должен описывать неопределённость именно этой величины, а не отдельных конверсий.

# %%
point_uplift = None
assert point_uplift is not None
assert -0.2 < float(point_uplift) < 0.2
print(round(float(point_uplift), 5))

# %% [markdown]
# ## 0.2. Контракт bootstrap
#
# Зафиксируйте единицу ресемплирования, число повторов и квантили до расчёта. Группы A и B ресемплируются раздельно и с возвращением.

# %%
bootstrap_plan = None
assert bootstrap_plan is not None
assert bootstrap_plan['unit'] == 'user'
assert bootstrap_plan['replace'] is True
assert int(bootstrap_plan['n_iter']) >= 1000
assert tuple(bootstrap_plan['quantiles']) == (0.025, 0.975)
print(bootstrap_plan)

# %% [markdown]
# ## 1. Bootstrap CI для разности конверсий B-A
#
# **Контракт раздела.** Сначала назовите ожидаемый объект и его смысл, затем замените заглушки. Проверяйте не только тип, но и диапазон, форму или инвариант; после зелёного `assert` объясните результат одной фразой без причинного вывода.

# %%
rng = np.random.default_rng(380)
boot_diffs = []
ci_low = None
ci_high = None
assert len(boot_diffs) >= 1000
assert ci_low is not None and ci_high is not None
assert float(ci_low) < float(ci_high)
print(ci_low, ci_high)

# %% [markdown]
# ## 2. Интерпретация CI
#
# **Контракт раздела.** Сначала назовите ожидаемый объект и его смысл, затем замените заглушки. Проверяйте не только тип, но и диапазон, форму или инвариант; после зелёного `assert` объясните результат одной фразой без причинного вывода.

# %%
CI_NOTE = ''
assert len(CI_NOTE) > 120
print(CI_NOTE)

# %% [markdown]
# ## 3. Корреляция pages_viewed и converted
#
# **Контракт раздела.** Сначала назовите ожидаемый объект и его смысл, затем замените заглушки. Проверяйте не только тип, но и диапазон, форму или инвариант; после зелёного `assert` объясните результат одной фразой без причинного вывода.

# %%
corr_pages = None
assert corr_pages is not None
assert -1 <= float(corr_pages) <= 1
print(round(float(corr_pages), 4))

# %% [markdown]
# ## 4. Корреляция session_minutes и converted
#
# **Контракт раздела.** Сначала назовите ожидаемый объект и его смысл, затем замените заглушки. Проверяйте не только тип, но и диапазон, форму или инвариант; после зелёного `assert` объясните результат одной фразой без причинного вывода.

# %%
corr_time = None
assert corr_time is not None
assert -1 <= float(corr_time) <= 1
print(round(float(corr_time), 4))

# %% [markdown]
# ## 5. Почему корреляция не равна причинности
#
# **Контракт раздела.** Сначала назовите ожидаемый объект и его смысл, затем замените заглушки. Проверяйте не только тип, но и диапазон, форму или инвариант; после зелёного `assert` объясните результат одной фразой без причинного вывода.

# %%
CAUSE_NOTE = ''
assert len(CAUSE_NOTE) > 150
print(CAUSE_NOTE)

# %% [markdown]
# ## Выходной билет
#
# 1. Запишите одним предложением, что измеряет полученное число.
# 2. Назовите одно ограничение анализа.
# 3. Укажите, какое решение нельзя принимать только по точечной оценке.
#
# Перед сдачей перезапустите ноутбук целиком: `Restart & Run All` должен пройти без ошибок.
