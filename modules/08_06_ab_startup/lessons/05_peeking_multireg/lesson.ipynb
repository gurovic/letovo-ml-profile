# %% [markdown]
# # Peeking risk и множественная линейная регрессия

# %%
from pathlib import Path
import numpy as np
import pandas as pd


def _find(name: str) -> Path:
    for p in (Path(name), Path(f'../../data/{name}'), Path(f'../data/{name}')):
        if p.exists():
            return p.resolve()
    raise FileNotFoundError(f'{name} не найден рядом с ноутбуком')


CSV_PATH = _find('startup_ab.csv')
df = pd.read_csv(CSV_PATH)
df['variant_b'] = (df['variant'] == 'B').astype(int)

# %% [markdown]
# ## 1. Накопительный p-value по дням

# %%
def perm_p(frame, seed=0, n_iter=1200):
    return None


daily = None
first_sig_day = None
assert daily is not None
assert {'day', 'p_value'} <= set(daily.columns)
assert first_sig_day is not None
print(daily.head(), first_sig_day)

# %% [markdown]
# ## 2. Почему peeking опасен

# %%
PEEK_NOTE = ''
assert len(PEEK_NOTE) > 140
print(PEEK_NOTE)

# %% [markdown]
# ## 3. Подготовка признаков для LinearRegression

# %%
X = None
y = None
assert X is not None and y is not None
assert X.shape[0] == len(df) and len(y) == len(df)
print(X.columns.tolist())

# %% [markdown]
# ## 4. Обучение модели и коэффициенты

# %%
from sklearn.linear_model import LinearRegression

model = None
coef_table = None
r2 = None
assert model is not None and coef_table is not None and r2 is not None
assert {'feature', 'coef'} <= set(coef_table.columns)
print(coef_table)
print(r2)

# %% [markdown]
# ## 5. Интерпретация коэффициента variant_b

# %%
VARIANT_NOTE = ''
assert len(VARIANT_NOTE) > 120
print(VARIANT_NOTE)

# %% [markdown]
# ## 6. Ограничения линейной регрессии для 0/1 target

# %%
LIN_NOTE = ''
assert len(LIN_NOTE) > 150
print(LIN_NOTE)
