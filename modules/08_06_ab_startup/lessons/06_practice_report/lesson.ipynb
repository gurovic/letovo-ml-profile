# %% [markdown]
# # Практика: итоговый A/B отчёт

# %% [markdown]
# ## Маршрут работы
#
# **Фокус:** От расчётов к проверяемому решению.
#
# Собираем метрику, p-value, CI, модель факторов и ограничения в единый отчёт. Рекомендация считается готовой только тогда, когда каждое утверждение опирается на число.
#
# **Правило работы:** выполняйте ячейки сверху вниз, заменяйте `None` и пустые строки, а после каждого шага добивайтесь зелёных `assert`. Не удаляйте проверки: они задают контракт результата.
#
# **Что сдаём:** выполненный ноутбук, численный результат и короткую интерпретацию без причинных обещаний.

# %%
from pathlib import Path
import numpy as np
import pandas as pd


def _find(name: str) -> Path:
    for p in (Path(name), Path(f'../../data/{name}'), Path(f'../data/{name}')):
        if p.exists():
            return p.resolve()
    raise FileNotFoundError(f'{name} не найден рядом с ноутбуком')


CSV_PATH = _find('startup_ab.csv')
df = pd.read_csv(CSV_PATH)
df['variant_b'] = (df['variant'] == 'B').astype(int)

# %% [markdown]
# ## 0.1. Адресат и решение отчёта
#
# До расчётов зафиксируйте, кто читает отчёт и какое решение он поддерживает. Это определяет нужные единицы, ограничения и уровень детализации.

# %%
report_contract = None
assert report_contract is not None
assert report_contract['audience'] == 'product team'
assert report_contract['decision'] in {'ship B', 'keep A', 'continue experiment'}
assert report_contract['estimand'] == 'conv_B - conv_A'
print(report_contract)

# %% [markdown]
# ## 0.2. Практический порог эффекта
#
# Задайте минимально полезный uplift в абсолютных долях до просмотра результата. Статистическая значимость не заменяет проверку продуктовой значимости.

# %%
min_practical_uplift = None
MDE_NOTE = ''
assert min_practical_uplift is not None
assert 0 < float(min_practical_uplift) < 0.1
assert len(MDE_NOTE) > 90
print(min_practical_uplift, MDE_NOTE)

# %% [markdown]
# ## 1. Соберите ключевые метрики
#
# **Контракт раздела.** Сначала назовите ожидаемый объект и его смысл, затем замените заглушки. Проверяйте не только тип, но и диапазон, форму или инвариант; после зелёного `assert` объясните результат одной фразой без причинного вывода.

# %%
summary = None
assert summary is not None
assert {'conv_a', 'conv_b', 'uplift'} <= set(summary.index)
print(summary)

# %% [markdown]
# ## 2. p-value и CI в одном месте
#
# **Контракт раздела.** Сначала назовите ожидаемый объект и его смысл, затем замените заглушки. Проверяйте не только тип, но и диапазон, форму или инвариант; после зелёного `assert` объясните результат одной фразой без причинного вывода.

# %%
p_value = None
ci = None
assert p_value is not None and ci is not None
assert len(ci) == 2
print(p_value, ci)

# %% [markdown]
# ## 3. Коэффициенты регрессии (top-3 по модулю)
#
# **Контракт раздела.** Сначала назовите ожидаемый объект и его смысл, затем замените заглушки. Проверяйте не только тип, но и диапазон, форму или инвариант; после зелёного `assert` объясните результат одной фразой без причинного вывода.

# %%
top_coef = None
assert top_coef is not None and len(top_coef) == 3
print(top_coef)

# %% [markdown]
# ## 4. Acceptance checklist
#
# **Контракт раздела.** Сначала назовите ожидаемый объект и его смысл, затем замените заглушки. Проверяйте не только тип, но и диапазон, форму или инвариант; после зелёного `assert` объясните результат одной фразой без причинного вывода.

# %%
acceptance = pd.Series(
    [False, False, False, False, False],
    index=['metric', 'p_value', 'ci', 'regression', 'limitations']
)
assert bool(acceptance.all())
print(acceptance)

# %% [markdown]
# ## 5. Итоговый REPORT
#
# **Контракт раздела.** Сначала назовите ожидаемый объект и его смысл, затем замените заглушки. Проверяйте не только тип, но и диапазон, форму или инвариант; после зелёного `assert` объясните результат одной фразой без причинного вывода.

# %%
REPORT = ''
READY = False
assert len(REPORT) > 450
assert READY is True
print(REPORT)

# %% [markdown]
# ## Выходной билет
#
# 1. Запишите одним предложением, что измеряет полученное число.
# 2. Назовите одно ограничение анализа.
# 3. Укажите, какое решение нельзя принимать только по точечной оценке.
#
# Перед сдачей перезапустите ноутбук целиком: `Restart & Run All` должен пройти без ошибок.
