# %% [markdown]
# # ДЗ: финальный артефакт отчёта

# %% [markdown]
# ## Маршрут работы
#
# **Фокус:** От расчётов к проверяемому решению.
#
# Собираем метрику, p-value, CI, модель факторов и ограничения в единый отчёт. Рекомендация считается готовой только тогда, когда каждое утверждение опирается на число.
#
# **Правило работы:** выполняйте ячейки сверху вниз, заменяйте `None` и пустые строки, а после каждого шага добивайтесь зелёных `assert`. Не удаляйте проверки: они задают контракт результата.
#
# **Что сдаём:** выполненный ноутбук, численный результат и короткую интерпретацию без причинных обещаний.

# %% [markdown]
# ## A. Закрепление и Challenge
#
# Задачи **A** повторяют основной приём пары на новом срезе данных. Задачи **Challenge** требуют самостоятельно выбрать процедуру и защитить интерпретацию. Сначала добейтесь корректного кода, затем пишите вывод.

# %%
from pathlib import Path
import numpy as np
import pandas as pd


def _find(name: str) -> Path:
    for p in (Path(name), Path(f'../../data/{name}'), Path(f'../data/{name}')):
        if p.exists():
            return p.resolve()
    raise FileNotFoundError(f'{name} не найден рядом с ноутбуком')


CSV_PATH = _find('startup_ab.csv')
df = pd.read_csv(CSV_PATH)
df['variant_b'] = (df['variant'] == 'B').astype(int)

# %% [markdown]
# ### A. Закрепление
#
# ## 1. Одна строка executive summary

# %%
EXEC_SUMMARY = ''
assert len(EXEC_SUMMARY) > 120
print(EXEC_SUMMARY)

# %% [markdown]
# ## 2. Риски и ограничения

# %%
RISKS = ''
assert len(RISKS) > 180
print(RISKS)

# %% [markdown]
# ### Challenge
#
# ## 3. План следующего эксперимента

# %%
NEXT_AB = ''
assert len(NEXT_AB) > 200
print(NEXT_AB)

# %% [markdown]
# ## 4. Рефлексия про статистический вывод

# %%
REFLECTION = ''
assert len(REFLECTION) > 180
print(REFLECTION)

# %% [markdown]
# ## Чек-лист домашней работы
#
# - [ ] Все `assert` зелёные.
# - [ ] Seed сохранён, результат воспроизводится.
# - [ ] В выводе названы эффект, неопределённость и ограничение.
# - [ ] Корреляция или коэффициент модели не названы доказательством причины.
