# %% [markdown]
# # ДЗ: устойчивая загрузка

# %%
from pathlib import Path
import pandas as pd

# %% [markdown]
# ## 1. safe_load
#
# `safe_load(path)` возвращает DataFrame или `None` при `FileNotFoundError` (не пробрасывает исключение).

# %%
def safe_load(path):
    pass


assert safe_load(Path('no_such_file.csv')) is None

# %% [markdown]
# ## 2. Успешный путь
#
# `safe_load` на реальном `trips.csv` возвращает непустой DataFrame.

# %%
path = None
for p in (Path('trips.csv'), Path('../../data/trips.csv'), Path('../data/trips.csv')):
    if p.exists():
        path = p
        break
ok = safe_load(path)
assert ok is not None and len(ok) > 0
print(ok.shape)

# %% [markdown]
# ## 3. Вызов
#
# `clean_trips` не должен трогать строки, где NaN только в `zone` (ключевые — distance и duration).

# %%
from copy import deepcopy
# переиспользуйте clean_trips из урока или скопируйте реализацию сюда
def clean_trips(raw: pd.DataFrame) -> pd.DataFrame:
    pass


demo = pd.DataFrame({
    'distance_km': [1.0, 2.0],
    'duration_min': [10.0, 20.0],
    'zone': [None, 'center'],
})
out = clean_trips(demo)
assert len(out) == 2
print(out)
