# %% [markdown]
# # ДЗ: устойчивая загрузка

# %%
from pathlib import Path
import pandas as pd

# %% [markdown]
# ## 1. Обёртка
#
# Функция `safe_load(path)` возвращает DataFrame или `None` при FileNotFoundError.

# %%
def safe_load(path):
    try:
        return pd.read_csv(path)
    except FileNotFoundError:
        return None
