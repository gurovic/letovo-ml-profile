# %% [markdown]
# # train/test и LinearRegression

# %%
from pathlib import Path
import pandas as pd


def find_trips_csv() -> Path:
    for p in (Path('trips.csv'), Path('../../data/trips.csv'), Path('../data/trips.csv')):
        if p.exists():
            return p.resolve()
    raise FileNotFoundError('trips.csv не найден')


TRIPS_PATH = find_trips_csv()
df = pd.read_csv(TRIPS_PATH)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## 1. Признак и цель
#
# Соберите `X` как DataFrame из одного столбца `distance_km` и `y` — Series `duration_min`. Важно: двойные скобки у X.

# %%
X = None
y = None
assert X is not None and y is not None
assert list(X.columns) == ['distance_km']
assert X.shape[1] == 1
assert len(y) == len(X)
print(X.shape, y.shape)

# %% [markdown]
# ## 2. train/test split
#
# 20% в test, `random_state=42`.

# %%
X_train = X_test = y_train = y_test = None
# train_test_split(...)
assert X_test is not None
assert len(X_test) == int(0.2 * len(df))
assert len(X_train) + len(X_test) == len(df)
print(len(X_train), len(X_test))

# %% [markdown]
# ## 3. fit / predict
#
# Обучите `LinearRegression` на train, предскажите test. Выведите `coef_` и `intercept_`.

# %%
model = None
y_pred = None
assert model is not None and y_pred is not None
assert len(y_pred) == len(y_test)
print('coef', model.coef_, 'intercept', model.intercept_)
print('первые 3 pred:', y_pred[:3])

# %% [markdown]
# ## 4. Расширение
#
# Повторите split с тем же `test_size` и `random_state=0`. Совпадают ли первые 3 индекса `y_test` с предыдущим split? Запишите ответ bool.

# %%
same_first_indices = None  # True/False после эксперимента
assert same_first_indices is False
print(same_first_indices)
