# %% [markdown]
# # Несколько признаков (обзор)
#
# Можно ли улучшить R², добавив `hour` к `distance_km`? Обзорно: два столбца в `X`, тот же seed, сравнение с одним признаком.

# %%
from pathlib import Path
import pandas as pd


def find_trips_csv() -> Path:
    for p in (Path('trips.csv'), Path('../../data/trips.csv'), Path('../data/trips.csv')):
        if p.exists():
            return p.resolve()
    raise FileNotFoundError('trips.csv не найден')


TRIPS_PATH = find_trips_csv()
df = pd.read_csv(TRIPS_PATH)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ## 1. X из двух столбцов
#
# Соберите `X = df[['distance_km', 'hour']]`, `y = duration_min`. Проверьте `X.shape[1] == 2`.

# %%
X = None
y = None
assert X is not None and y is not None
assert list(X.columns) == ['distance_km', 'hour']
assert X.shape[1] == 2
print(X.shape)

# %% [markdown]
# ## 2. Модель на двух признаках
#
# Split 0.2 / seed 42. Обучите модель; сохраните `r2_two` и посмотрите `coef_` (два числа — по одному на признак).

# %%
model = None
r2_two = None
assert model is not None and r2_two is not None
assert len(model.coef_) == 2
assert isinstance(r2_two, (int, float))
print('coef', model.coef_, 'R2', round(float(r2_two), 3))

# %% [markdown]
# ## 3. Сравнение с одним признаком
#
# Тот же seed: R² только на `distance_km` → `r2_one`. Запишите в `two_better`, улучшил ли второй признак R² на test (на этих данных ответ может быть **False** — это нормально для обзора).

# %%
r2_one = None
two_better = None  # True/False: r2_two > r2_one
assert r2_one is not None
assert two_better == (r2_two > r2_one)
print('one', round(float(r2_one), 3), 'two', round(float(r2_two), 3), 'two_better', two_better)

# %% [markdown]
# ## 4. Когда второй признак мешает
#
# **Why может упасть R² на test:** шум, корреляция признаков, мало данных, линейная модель не ловит взаимодействие.
#
# 1–2 предложения в `WHEN_HURTS` — без «магии».

# %%
WHEN_HURTS = ''
assert len(WHEN_HURTS) > 30
print(WHEN_HURTS)

# %% [markdown]
# ## 5. Правило для отчёта
#
# Кратко в `MULTI_NOTE`: зачем пробовать второй признак и почему «больше столбцов» не гарантирует лучший R² на test?

# %%
MULTI_NOTE = ''
assert len(MULTI_NOTE) > 30
print(MULTI_NOTE)

# %% [markdown]
# ## 6. Практика: MSE двух признаков
#
# Запишите MSE на test для модели distance+hour (тот же split).

# %%
mse_two = None
assert mse_two is not None and mse_two >= 0
print('MSE two', round(float(mse_two), 2))

# %% [markdown]
# ## 7. Checkpoint: интерпретация coef_
#
# Одна фраза: можно ли читать `coef_[1]` (hour) как «минуты на час суток» без оговорок, если в модели уже есть distance?

# %%
COEF_READ_NOTE = ''
assert len(COEF_READ_NOTE) > 25
print(COEF_READ_NOTE)
