# %% [markdown]
# # ДЗ: обзор нескольких признаков

# %%
from pathlib import Path
import pandas as pd


def find_trips_csv() -> Path:
    for p in (Path('trips.csv'), Path('../../data/trips.csv'), Path('../data/trips.csv')):
        if p.exists():
            return p.resolve()
    raise FileNotFoundError('trips.csv не найден')


TRIPS_PATH = find_trips_csv()
df = pd.read_csv(TRIPS_PATH)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### A. Закрепление

# %% [markdown]
# ## 1. MSE двух признаков
#
# MSE на test для distance+hour (seed 42, test 0.2).

# %%
mse_two = None
assert mse_two is not None and mse_two >= 0
print(round(float(mse_two), 2))

# %% [markdown]
# ### B. Вызов
#
# ## 2. Третий признак
#
# Добавьте `is_comfort` (0/1) к distance+hour. Вырос ли R² относительно двух признаков? Ответ bool + одна фраза ограничения обзора.

# %%
improved = None
LIMIT_NOTE = ''
assert improved in (True, False)
assert len(LIMIT_NOTE) > 15
print(improved, LIMIT_NOTE)

# %% [markdown]
# ## 3. Когда не добавлять
#
# 2 предложения: в каких условиях вы оставите один признак в сдаче, даже если «можно» добавить второй.

# %%
KEEP_ONE_NOTE = ''
assert len(KEEP_ONE_NOTE) > 30
print(KEEP_ONE_NOTE)
