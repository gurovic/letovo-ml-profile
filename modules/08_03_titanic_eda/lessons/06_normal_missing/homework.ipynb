# %% [markdown]
# # ДЗ: ЦПТ и пропуски

# %%
from pathlib import Path
import pandas as pd


def find_titanic_csv() -> Path:
    for p in (Path('titanic.csv'), Path('../../data/titanic.csv'), Path('../data/titanic.csv')):
        if p.exists():
            return p.resolve()
    raise FileNotFoundError('titanic.csv не найден — положите файл рядом с ноутбуком')


TITANIC_PATH = find_titanic_csv()
df = pd.read_csv(TITANIC_PATH)

import numpy as np

# %% [markdown]
# ### A. Закрепление

# %% [markdown]
# ## 1. 100 средних age (sample n=25) — std этих средних

# %%
std_of_means = None
assert std_of_means is not None and float(std_of_means) > 0
print(std_of_means)

# %% [markdown]
# ## 2. Число NA в embark_town и embarked — совпадают ли?

# %%
na_et = None
na_e = None
SAME = None  # bool
assert na_et is not None and na_e is not None and SAME is not None
assert bool(SAME) is True
print(na_et, na_e, SAME)

# %% [markdown]
# ### B. Вызов
#
# ## 3. Сравнение долей survived: полный df vs dropna(age)
#
# `rate_all` vs `rate_age_known`. Разница и комментарий `AGE_NA_BIAS`.

# %%
rate_all = float(df['survived'].mean())
rate_age_known = None
AGE_NA_BIAS = ''
assert rate_age_known is not None
assert len(AGE_NA_BIAS) > 30
print(rate_all, rate_age_known, AGE_NA_BIAS)

# %% [markdown]
# ## 4. Почему дубликаты в seaborn-Titanic возможны
#
# `DUP_NOTE` — 2–3 предложения (агрегация полей / учебная версия).

# %%
DUP_NOTE = ''
assert len(DUP_NOTE) > 40
print(DUP_NOTE)
