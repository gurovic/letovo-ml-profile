# %% [markdown]
# # ДЗ: sampling bias

# %%
from pathlib import Path
import pandas as pd


def find_titanic_csv() -> Path:
    for p in (Path('titanic.csv'), Path('../../data/titanic.csv'), Path('../data/titanic.csv')):
        if p.exists():
            return p.resolve()
    raise FileNotFoundError('titanic.csv не найден — положите файл рядом с ноутбуком')


TITANIC_PATH = find_titanic_csv()
df = pd.read_csv(TITANIC_PATH)

# %% [markdown]
# ### A. Закрепление

# %% [markdown]
# ## 1. rate только female и только pclass==3

# %%
rate_f = None
rate_p3 = None
true_rate = float(df['survived'].mean())
assert rate_f is not None and rate_p3 is not None
assert float(rate_f) > true_rate and float(rate_p3) < true_rate
print(rate_f, rate_p3, true_rate)

# %% [markdown]
# ### B. Вызов
#
# ## 2. Симуляция: 20 выборок по 30 строк
#
# Список из 20 mean(survived) с random_state=0..19. Запишите min и max списка → `sim_min`, `sim_max`.

# %%
sim_min = None
sim_max = None
assert sim_min is not None and sim_max is not None
assert float(sim_min) < float(sim_max)
print(sim_min, sim_max)

# %% [markdown]
# ## 3. Опровержение
#
# «Большая выборка всегда репрезентативна». Почему на примере Titanic это неверно? → `BIG_N_MYTH`.

# %%
BIG_N_MYTH = ''
assert len(BIG_N_MYTH) > 40
print(BIG_N_MYTH)
