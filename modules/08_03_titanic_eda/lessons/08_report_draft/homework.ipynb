# %% [markdown]
# # ДЗ: дописать черновик отчёта

# %%
from pathlib import Path
import pandas as pd


def find_titanic_csv() -> Path:
    for p in (Path('titanic.csv'), Path('../../data/titanic.csv'), Path('../data/titanic.csv')):
        if p.exists():
            return p.resolve()
    raise FileNotFoundError('titanic.csv не найден — положите файл рядом с ноутбуком')


TITANIC_PATH = find_titanic_csv()
df = pd.read_csv(TITANIC_PATH)

# %% [markdown]
# ### A. Закрепление

# %% [markdown]
# ## 1. Добавьте в headline сравнение who=child vs adult_male

# %%
rate_child = None
rate_am = None
assert rate_child is not None and rate_am is not None
assert float(rate_child) > float(rate_am)
print(rate_child, rate_am)

# %% [markdown]
# ### B. Вызов
#
# ## 2. Markdown-черновик `report_md`
#
# Строка с заголовками ## Данные / ## Находки / ## Ограничения / ## Вывод (можно без реальных картинок inline — укажите имена файлов figures/).

# %%
report_md = ''
assert '## Данные' in report_md and '## Вывод' in report_md
assert '## Ограничения' in report_md
assert len(report_md) > 300
print(report_md[:500])

# %% [markdown]
# ## 3. Запрет модели
#
# Найдите и удалите из своего текста любые намёки на обучение классификатора. `NO_MODEL_CONFIRM = True` только если текст чист.

# %%
NO_MODEL_CONFIRM = False
assert NO_MODEL_CONFIRM is True
print('ok')
