# %% [markdown]
# # ДЗ: сегменты и membership

# %%
from pathlib import Path
import numpy as np
import pandas as pd


def _find(name: str) -> Path:
    for p in (Path(name), Path(f'../../data/{name}'), Path(f'../data/{name}')):
        if p.exists():
            return p.resolve()
    raise FileNotFoundError(f'{name} не найден рядом с ноутбуком')


CSV_PATH = _find('orders_slim.csv')
df = pd.read_csv(
    CSV_PATH,
    parse_dates=['order_purchase_timestamp', 'order_estimated_delivery_date', 'order_delivered_customer_date'],
)

# %% [markdown]
# ## 1. Отметить 10 заказов для ручной проверки

# %%
watch = set()
assert len(watch) == 10
print(watch)

# %% [markdown]
# ## 2. Пояснение по качеству сегментации

# %%
SEG_NOTE = ''
assert len(SEG_NOTE) > 120
print(SEG_NOTE)
