# %% [markdown]
# # ДЗ: кластерный отчёт для хаба

# %%
from pathlib import Path
import numpy as np
import pandas as pd


def find_orders_csv():
    for path in (
        Path("orders_slim.csv"),
        Path("../orders_slim.csv"),
        Path("../../data/orders_slim.csv"),
        Path("../data/orders_slim.csv"),
        Path("../../../data/orders_slim.csv"),
    ):
        if path.exists():
            return path.resolve()
    return (
        "https://raw.githubusercontent.com/gurovic/letovo-ml-profile/main/"
        "modules/08_08_logistics_clustering/data/orders_slim.csv"
    )


CSV_PATH = find_orders_csv()
DATE_COLUMNS = [
    "order_purchase_timestamp",
    "order_estimated_delivery_date",
    "order_delivered_customer_date",
]
df = pd.read_csv(CSV_PATH, parse_dates=DATE_COLUMNS)
assert len(df) > 0
assert df["order_id"].notna().all()
print(f"Загружено заказов: {len(df)}")

from sklearn.cluster import DBSCAN, KMeans
from sklearn.preprocessing import StandardScaler

FEATURES = ["delivery_days", "freight_value", "delay_days"]

# %% [markdown]
# ### Part A — обязательно
#
# ## A1. Повторяемый pipeline

# %%
def cluster_orders(frame, eps=0.9):
    # TODO: вернуть копию с cluster_km и cluster_db
    ...


result = cluster_orders(df)
assert len(result) == len(df)
assert {"cluster_km", "cluster_db"} <= set(result.columns)

# %% [markdown]
# ## A2. Таблица аномалий
#
# Не более 12 строк, DBSCAN noise или top-delay.

# %%
anomaly_table = None  # TODO
assert isinstance(anomaly_table, pd.DataFrame)
assert 1 <= len(anomaly_table) <= min(12, len(df))
assert {"order_id", "delay_days", "freight_value", "cluster_db"} <= set(anomaly_table.columns)

# %% [markdown]
# ## A3. Проверки качества

# %%
checks = {"rows_preserved": None, "three_features": None, "late_not_feature": None, "ranked": None}  # TODO
assert set(checks.values()) == {True}

# %% [markdown]
# ### Challenge
#
# ## B1. Чувствительность списка
#
# Сравните anomaly ids при eps 0.7 и 1.1.

# %%
ids_07 = set()  # TODO
ids_11 = set()  # TODO
jaccard = None  # TODO
assert 0 <= jaccard <= 1
assert isinstance(ids_07, set) and isinstance(ids_11, set)

# %% [markdown]
# ## B2. Executive note

# %%
EXECUTIVE_NOTE = ""  # TODO: 300+ символов, наблюдение/действие/ограничение
assert len(EXECUTIVE_NOTE) >= 300
assert all(word in EXECUTIVE_NOTE.lower() for word in ["кластер", "аномал", "огранич"])
