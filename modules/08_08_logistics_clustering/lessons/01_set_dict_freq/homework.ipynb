# %% [markdown]
# # ДЗ: set, dict и частоты

# %%
from pathlib import Path
import numpy as np
import pandas as pd


def find_orders_csv():
    for path in (
        Path("orders_slim.csv"),
        Path("../orders_slim.csv"),
        Path("../../data/orders_slim.csv"),
        Path("../data/orders_slim.csv"),
        Path("../../../data/orders_slim.csv"),
    ):
        if path.exists():
            return path.resolve()
    return (
        "https://raw.githubusercontent.com/gurovic/letovo-ml-profile/main/"
        "modules/08_08_logistics_clustering/data/orders_slim.csv"
    )


CSV_PATH = find_orders_csv()
DATE_COLUMNS = [
    "order_purchase_timestamp",
    "order_estimated_delivery_date",
    "order_delivered_customer_date",
]
df = pd.read_csv(CSV_PATH, parse_dates=DATE_COLUMNS)
assert len(df) > 0
assert df["order_id"].notna().all()
print(f"Загружено заказов: {len(df)}")

# %% [markdown]
# ### Part A — обязательно
#
# ## A1. Уникальные продавцы

# %%
seller_ids = None  # TODO
assert isinstance(seller_ids, set)
assert len(seller_ids) == df["seller_id"].nunique()

# %% [markdown]
# ## A2. Late по seller_id

# %%
seller_late = {}  # TODO
assert sum(seller_late.values()) == int(df["is_late"].sum())
assert set(seller_late) <= seller_ids

# %% [markdown]
# ## A3. Top-5

# %%
top5_sellers = None  # TODO: список пар
assert 1 <= len(top5_sellers) <= 5
assert all(top5_sellers[i][1] >= top5_sellers[i + 1][1] for i in range(len(top5_sellers) - 1))

# %% [markdown]
# ### Challenge
#
# ## B1. Универсальная таблица

# %%
state_table = None  # TODO: DataFrame из late_stats
assert isinstance(state_table, pd.DataFrame)
assert {"segment", "late", "total", "rate"} <= set(state_table.columns)
assert len(state_table) == df["seller_state"].nunique()

# %% [markdown]
# ## B2. Интерпретация

# %%
FREQUENCY_NOTE = ""  # TODO: count против rate и размер сегмента
assert len(FREQUENCY_NOTE) >= 180
assert "late" in FREQUENCY_NOTE.lower()
