# %% [markdown]
# # Практика буферов: поток заказов

# %%
from pathlib import Path
import numpy as np
import pandas as pd


def _find(name: str) -> Path:
    for p in (Path(name), Path(f'../../data/{name}'), Path(f'../data/{name}')):
        if p.exists():
            return p.resolve()
    raise FileNotFoundError(f'{name} не найден рядом с ноутбуком')


CSV_PATH = _find('orders_slim.csv')
df = pd.read_csv(
    CSV_PATH,
    parse_dates=['order_purchase_timestamp', 'order_estimated_delivery_date', 'order_delivered_customer_date'],
)

from collections import deque

# %% [markdown]
# ## 1. Буфер последних 7 заказов

# %%
recent = deque(maxlen=7)
for oid in df['order_id']:
    pass
assert len(recent) == 7
print(list(recent))

# %% [markdown]
# ## 2. Две очереди: late и normal

# %%
late_q = deque()
normal_q = deque()
n_late = None
n_norm = None
assert n_late is not None and n_norm is not None
print(n_late, n_norm)

# %% [markdown]
# ## 3. Симуляция 12 тиков обработки

# %%
processed = []
assert len(processed) == 12
print(processed)
