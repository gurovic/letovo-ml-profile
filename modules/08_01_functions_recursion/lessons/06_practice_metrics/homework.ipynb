# %% [markdown]
# # Домашнее задание: отладка счётчика

# %% [markdown]
# ## 1. `increment` без global
#
# Перепишите так, чтобы счётчик передавался аргументом и возвращался новое значение (как в `homework_counter.py`, но **без** `global`).

# %%
def increment(counter):
    pass


c = 0
c = increment(c)
c = increment(c)
# assert c == 2

# %% [markdown]
# ## 2. `reset_and_count`
#
# Сумма списка — не забудьте `return`.

# %%
def reset_and_count(items):
    total = 0
    for x in items:
        total += x
    pass


# assert reset_and_count([1, 2, 3]) == 6

# %% [markdown]
# ## 3. Журнал
#
# Markdown-ячейка: для **каждой** из двух функций выше — симптом → причина → исправление (как на паре).

# %% [markdown]
# ## 4. precision и recall (по желанию)
#
# Из `confusion_counts` с пары: `precision = tp / (tp + fp)`, `recall = tp / (tp + fn)`. Посчитайте на `PREDICTIONS`/`LABELS`.

# %%
PREDICTIONS = [1, 0, 1, 1, 0, 1, 1, 0, 1, 0]
LABELS =      [1, 0, 1, 0, 0, 1, 1, 0, 1, 1]
# tp, fp, fn, tn = ...
# precision, recall
