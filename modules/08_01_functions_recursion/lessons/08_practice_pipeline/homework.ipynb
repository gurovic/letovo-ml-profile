# %% [markdown]
# # Домашнее задание: углубление серии (пара 8)
#
# Если на паре не успели — дорешайте **A3, B3, C2** из `lesson.ipynb`.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('../..').resolve()))
from data.module_datasets import (
    APARTMENTS, EXAM_SCORES, PREDICTIONS, LABELS,
    NESTED_API_RESPONSE, CATEGORY_TREE, FEATURE_ROWS,
    MODEL_RUNS, FEATURE_POINTS,
    PRICE_INTERCEPT, PRICE_COEF_AREA,
)

# %% [markdown]
# ## 1. Опора
#
# Скопируйте с пары минимум A1–A2, B1–B2, C1 (если ещё не сделано).

# %%
# extract_ids, walk_categories, apply_pipeline + шаги pipeline

# %% [markdown]
# ## 2. A3. `count_leaves`

# %%
def count_leaves(node):
    pass


# assert count_leaves(CATEGORY_TREE) >= 4

# %% [markdown]
# ## 3. B3. Farthest point
#
# `max(FEATURE_POINTS, key=…)` — точка с максимальной суммой квадратов координат.

# %%
# farthest = max(FEATURE_POINTS, key=lambda p: ...)
# print(farthest)

# %% [markdown]
# ## 4. C2. Текстовый pipeline
#
# Соберите pipeline: strip → lower → split → оставить токены длиной ≥ 4. Проверьте на строке `'  Data science ML course  '`.

# %%
text_pipeline = [
    lambda s: s.strip().lower(),
    lambda s: s.split(),
    lambda tokens: [t for t in tokens if len(t) >= 4],
]
# print(apply_pipeline('  Data science ML course  ', text_pipeline))
