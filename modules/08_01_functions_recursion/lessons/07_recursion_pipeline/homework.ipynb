# %% [markdown]
# # Домашнее задание: рекурсия + 1 задача на lambda
#
# В этом ДЗ: **4 отдельные задачи на рекурсию** и **1 задача на `lambda`**.
# Задачи не повторяют задания из урока (без `flatten`, `count_leaves`, `extract_ids`).

# %% [markdown]
# ## 1. Данные
#
# Запустите ячейку ниже — это входные данные для всех заданий.

# %%
NESTED_NUMBERS = [2, [1, [3, 4], 5], [[6], 7]]

FILE_TREE = {
    "name": "project",
    "files": ["README.md"],
    "children": [
        {
            "name": "src",
            "files": ["main.py", "utils.py"],
            "children": [
                {"name": "models", "files": ["model.py"], "children": []},
                {"name": "tests", "files": ["test_main.py"], "children": []},
            ],
        },
        {"name": "docs", "files": ["guide.md"], "children": []},
    ],
}

BRACKETS_OK = "((()())(()))"
BRACKETS_BAD = "(()))("

PRODUCTS = [
    {"name": "airpods", "price": 199, "rating": 4.7},
    {"name": "mouse", "price": 49, "rating": 4.4},
    {"name": "keyboard", "price": 99, "rating": 4.6},
    {"name": "monitor", "price": 299, "rating": 4.8},
]

# %% [markdown]
# ## 2. `sum_nested(numbers)` (рекурсия)
#
# Реализуйте функцию, которая рекурсивно суммирует все числа во вложенном списке.
# Для `NESTED_NUMBERS` ожидается `28`.

# %%
def sum_nested(numbers):
    pass


# assert sum_nested(NESTED_NUMBERS) == 28

# %% [markdown]
# ## 3. `max_depth(items)` (рекурсия)
#
# Глубина числа = `0`, глубина списка = `1 + max(глубин элементов)`.
# Найдите глубину `NESTED_NUMBERS` (ответ: `3`).

# %%
def max_depth(items):
    pass


# assert max_depth(NESTED_NUMBERS) == 3

# %% [markdown]
# ## 4. `count_files(node)` (рекурсия)
#
# В дереве `FILE_TREE` у каждого узла есть поля `files` и `children`.
# Напишите функцию, которая считает общее число файлов во всём дереве.
# Для `FILE_TREE` ожидается `6`.

# %%
def count_files(node):
    pass


# assert count_files(FILE_TREE) == 6

# %% [markdown]
# ## 5. `is_balanced(s, idx=0, balance=0)` (рекурсия)
#
# Проверьте рекурсивно корректность скобочной последовательности.
# Используйте параметры `idx` и `balance` без циклов.
# Строка состоит только из символов `(` и `)`.

# %%
def is_balanced(s, idx=0, balance=0):
    pass


# assert is_balanced(BRACKETS_OK) is True
# assert is_balanced(BRACKETS_BAD) is False

# %% [markdown]
# ## 6. Lambda: `best_product`
#
# Найдите товар с лучшим соотношением `rating / price` через `max(..., key=lambda ...)`.
# Для `PRODUCTS` ожидается товар `"mouse"`.

# %%
best_product = None
# best_product = max(PRODUCTS, key=lambda item: ...)

# assert best_product["name"] == "mouse"
