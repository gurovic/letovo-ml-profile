# %% [markdown]
# # Домашнее задание: практика transform

# %%
LAB_SCORES = [72, 81, 55, 90, 44, 38, 92, 58]
# Строка признаков: числа + название района (строка не входит в статистику)
FEATURE_ROWS = [
    (28, 1, 3, 'north'),
    (45, 2, 7, 'center'),
    (60, 3, 12, 'south'),
    (32, 1, 2, 'west'),
]

# %% [markdown]
# ## 1. Опора
#
# Скопируйте с пары 3–4: `describe_numbers`, `min_max_scale`, `clip_outlier`, `grade_stats`, `apply_transform`.

# %%
# ваши функции

# %% [markdown]
# ## 2. `numeric_stats_from_row`
#
# Для кортежа `row` верните `(mean, max)` только по **числовым** элементам (подсказка: `isinstance(x, (int, float))`). Проверьте на `FEATURE_ROWS[0]`.

# %%
def numeric_stats_from_row(row):
    pass


# assert numeric_stats_from_row(FEATURE_ROWS[0]) == (...)

# %% [markdown]
# ## 3. `transform_pipeline`
#
# Напишите `transform_pipeline(values, *fns)` — последовательно применить все функции. Сравните `describe_numbers(min_max_scale(LAB_SCORES))` и цепочку `clip [50,95] → scale` через pipeline (mean до и после в комментарии).

# %%
def clip_scores(scores, low, high):
    pass


def transform_pipeline(values, *fns):
    pass


# сравнение mean

# %% [markdown]
# ## 4. Обоснование preprocess
#
# Добавьте **markdown-ячейку** (3–4 предложения): на `LAB_SCORES` что сильнее меняет смысл `mean` — только `min_max_scale` или сначала clip в [50, 95], потом scale? Опирайтесь на числа из §3.
