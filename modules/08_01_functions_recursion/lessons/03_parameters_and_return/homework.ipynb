# %% [markdown]
# # Домашнее задание: параметры и return

# %%
EXAM_SCORES = [40, 55, 62, 75, 88, 91, 48, 100, 33, 67]
AREAS_SQM = [28, 32, 45, 55, 60]
# Одна «строка» признаков — три числа с одним индексом
ROW_AREAS = [28, 45, 60, 32]
ROW_ROOMS = [1, 2, 3, 1]
ROW_FLOORS = [3, 7, 12, 2]

# %% [markdown]
# ## 1. Напоминание с пары
#
# Скопируйте из `lesson.ipynb` (или напишите заново): `describe_numbers`, `min_max_scale`, `clip_outlier`, `grade_stats`.

# %%
def describe_numbers(values):
    pass


def min_max_scale(values):
    pass


def clip_outlier(x, low, high):
    pass


def grade_stats(scores, pass_threshold=60):
    pass

# %% [markdown]
# ## 2. Clip всей выборки
#
# Напишите `clip_scores(scores, low, high)` — список с clip каждого балла. Обрежьте `EXAM_SCORES` в [50, 95]. Сравните `mean` до и после (через `describe_numbers`).

# %%
def clip_scores(scores, low, high):
    pass


# before, after, вывод mean

# %% [markdown]
# ## 3. Статистика по строке признаков
#
# `row_numeric_stats(area, rooms, floor)` → `(mean, max)` по трём числам. Проверьте на `ROW_*[0]`.

# %%
def row_numeric_stats(area, rooms, floor):
    pass


# assert на ROW_AREAS[0], ROW_ROOMS[0], ROW_FLOORS[0]

# %% [markdown]
# ## 4. Подбор порога
#
# Переберите `pass_threshold` от 40 до 95. Найдите порог, при котором доля сдавших ближе всего к 0.5. Запишите порог и долю.

# %%
# перебор; print('лучший порог = ...')
