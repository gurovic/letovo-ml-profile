# %% [markdown]
# # Практика: predict

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('../..').resolve()))
from data.module_datasets import (
    APARTMENTS, EXAM_SCORES, PREDICTIONS, LABELS,
    NESTED_API_RESPONSE, CATEGORY_TREE, FEATURE_ROWS,
    MODEL_RUNS, FEATURE_POINTS,
    PRICE_INTERCEPT, PRICE_COEF_AREA,
)

# %%
def predict_price(area_sqm):
    return PRICE_INTERCEPT + PRICE_COEF_AREA * area_sqm

# %% [markdown]
# ## Задача 1. `predict_pass` — бинарный класс

# %%
def predict_pass(score, threshold=60):
    """1 если сдал, 0 если нет."""
    pass


assert predict_pass(72) == 1
assert predict_pass(55) == 0
print('predict_pass OK')

# %% [markdown]
# ## Задача 2. `batch_predict` — список площадей
#
# Одна функция `predict_price` — один прогноз. `batch_predict` применяет её ко всему списку сразу.

# %%
def batch_predict(areas, predict_fn):
    """Применить predict_fn к каждому элементу areas."""
    pass


areas = [a['area_sqm'] for a in APARTMENTS]
preds = batch_predict(areas, predict_price)
assert len(preds) == len(areas)
print(preds)

# %% [markdown]
# ## Задача 3. `mae` — средняя абсолютная ошибка

# %%
def mae(preds, facts):
    """Среднее |pred - fact|."""
    pass


facts = [a['price_mln'] for a in APARTMENTS]
preds = batch_predict([a['area_sqm'] for a in APARTMENTS], predict_price)
# print(mae(preds, facts))

# %% [markdown]
# ## Задача 4. Выбор коэффициента
#
# Сравните MAE для двух коэффициентов площади (0.09 и 0.12). Запишите: «лучший коэффициент = …, MAE = …».

# %%
# ваш эксперимент и вывод

# %% [markdown]
# ## Домашнее задание
#
# `predict_room_price(area_sqm, rooms)` — как `predict_price`, плюс 0.3 млн за каждую комнату сверх 1. Проверьте на 2–3 примерах.

# %%
# ваш код
